# %% [markdown]
# <img src="ALMAARC.png" width="250" height="240"  align="right"/>
#
#
#
# <hr style="border:2px solid darkblue">
#
# # NB1. Query one source
#
# <hr style="border:2px solid darkblue">
#
# In this notebook we query one source in two modes:
# * By name
#     * Full name
#     * part of name
#
# * By coordinate:
#     * within a certain radius around a given coordinate (for point sources)
#     * within a certain radius around a given coordinate, estimating the distance to the archival sources
#
# -------------
#
# The relevant columns in the ALMA Archive datasets are
# * *s_ra*, *s_dec* (RAD and DEC in degress)
# * *target_name* (source name)
#
# --------- ----- -----

# %% [markdown]
# First we need to set up the python modules

# %%
import numpy as np
from astropy.table import Table
import pyvo
import pandas as pd

service = pyvo.dal.TAPService("https://almascience.eso.org/tap")

# %% [markdown]
# <hr style="border:2px solid darkblue"> </hr>
#
# ## By Name
#
# <hr style="border:2px solid darkblue"> </hr>

# %%
def query_name_exact(source_name):
    """ input: full source name """
    
    query = f"""  SELECT  *  
                FROM ivoa.obscore  
                WHERE  target_name = '{source_name}' """
    
    return service.search(query).to_table().to_pandas()


def query_name_included(source_name):
    """ input: part of source name  """
    
    query = f""" SELECT *  
            FROM ivoa.obscore  
            WHERE target_name LIKE '%{source_name}%'  """
    
    return service.search(query).to_table().to_pandas()

# %% [markdown]
# ## Example 1a: Query the source Centaurus A

# %%
query_name_exact("Centaurus A")
# Out:
#                                           access_url access_format  \
# 0  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 1  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 2  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 3  http://almascience.org/aq?member_ous_id=uid://...     text/html
#
#        proposal_id data_rights  gal_longitude  gal_latitude  \
# 0  2011.0.00008.SV      Public     309.512363     19.416239
# 1  2011.0.00008.SV      Public     309.512363     19.416239
# 2  2011.0.00008.SV      Public     309.512363     19.416239
# 3  2011.0.00008.SV      Public     309.512363     19.416239
#
#               obs_publisher_did obs_collection facility_name instrument_name  \
# 0  ADS/JAO.ALMA#2011.0.00008.SV           ALMA           JAO            ALMA
# 1  ADS/JAO.ALMA#2011.0.00008.SV           ALMA           JAO            ALMA
# 2  ADS/JAO.ALMA#2011.0.00008.SV           ALMA           JAO            ALMA
# 3  ADS/JAO.ALMA#2011.0.00008.SV           ALMA           JAO            ALMA
#
#    ...   frequency velocity_resolution   obs_creator_name  \
# 0  ...  238.261613         1183.847494  observatory, ALMA
# 1  ...  238.261613         1183.847494  observatory, ALMA
# 2  ...  238.261613         1183.847494  observatory, ALMA
# 3  ...  238.261613         1183.847494  observatory, ALMA
#
#                                            pub_title  \
# 0  ALMA Observations of the Physical and Chemical...
# 1  ALMA Observations of the Physical and Chemical...
# 2  ALMA Observations of the Physical and Chemical...
# 3  ALMA Observations of the Physical and Chemical...
#
#                                  first_author  qa2_passed  \
# 0  Azeez, Jazeel H. Israel, F. P. McCoy, Mark           T
# 1  Azeez, Jazeel H. Israel, F. P. McCoy, Mark           T
# 2  Azeez, Jazeel H. Israel, F. P. McCoy, Mark           T
# 3  Azeez, Jazeel H. Israel, F. P. McCoy, Mark           T
#
#                                        bib_reference  \
# 0  2014A&A...562A..96I 2017AdAst2017E...6A 2017Ap...
# 1  2014A&A...562A..96I 2017AdAst2017E...6A 2017Ap...
# 2  2014A&A...562A..96I 2017AdAst2017E...6A 2017Ap...
# 3  2014A&A...562A..96I 2017AdAst2017E...6A 2017Ap...
#
#                                      science_keyword  scientific_category  \
# 0  Galactic centres/nuclei, Active Galactic Nucle...      Active galaxies
# 1  Galactic centres/nuclei, Active Galactic Nucle...      Active galaxies
# 2  Galactic centres/nuclei, Active Galactic Nucle...      Active galaxies
# 3  Galactic centres/nuclei, Active Galactic Nucle...      Active galaxies
#
#               lastModified
# 0  2021-06-16T16:46:50.431
# 1  2021-06-16T16:46:50.431
# 2  2021-06-16T16:46:50.431
# 3  2021-06-16T16:46:50.431
#
# [4 rows x 63 columns]

# %% [markdown]
# ## Example 1b: Query the source name "centaurus"
# Since sourcenames in the ALMA proposals might be spelled differently, it is safe to search for parts of the names. We will see what results from the search of "centaurus".

# %%
table = query_name_included("centaurus")
table.head(5) ### showing only first 5 rows
# Out:
#                                           access_url access_format  \
# 0  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 1  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 2  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 3  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 4  http://almascience.org/aq?member_ous_id=uid://...     text/html
#
#        proposal_id data_rights  gal_longitude  gal_latitude  \
# 0   2012.1.00225.S      Public     309.515937     19.417346
# 1   2012.1.00225.S      Public     309.515937     19.417346
# 2   2012.1.00225.S      Public     309.515937     19.417346
# 3   2012.1.00225.S      Public     309.515937     19.417346
# 4  2011.0.00008.SV      Public     309.512363     19.416239
#
#               obs_publisher_did obs_collection facility_name instrument_name  \
# 0   ADS/JAO.ALMA#2012.1.00225.S           ALMA           JAO            ALMA
# 1   ADS/JAO.ALMA#2012.1.00225.S           ALMA           JAO            ALMA
# 2   ADS/JAO.ALMA#2012.1.00225.S           ALMA           JAO            ALMA
# 3   ADS/JAO.ALMA#2012.1.00225.S           ALMA           JAO            ALMA
# 4  ADS/JAO.ALMA#2011.0.00008.SV           ALMA           JAO            ALMA
#
#    ...   frequency velocity_resolution   obs_creator_name  \
# 0  ...  698.902241          413.199446     Espada, Daniel
# 1  ...  698.902241          413.199446     Espada, Daniel
# 2  ...  698.902241          413.199446     Espada, Daniel
# 3  ...  698.902241          413.199446     Espada, Daniel
# 4  ...  238.261613         1183.847494  observatory, ALMA
#
#                                            pub_title  \
# 0  ALMACAL I: First Dual-band Number Counts from ...
# 1  ALMACAL I: First Dual-band Number Counts from ...
# 2  ALMACAL I: First Dual-band Number Counts from ...
# 3  ALMACAL I: First Dual-band Number Counts from ...
# 4  ALMA Observations of the Physical and Chemical...
#
#                                  first_author  qa2_passed  \
# 0    Espada, D. Oteo, I. Thelen, Alexander E.           T
# 1    Espada, D. Oteo, I. Thelen, Alexander E.           T
# 2    Espada, D. Oteo, I. Thelen, Alexander E.           T
# 3    Espada, D. Oteo, I. Thelen, Alexander E.           T
# 4  Azeez, Jazeel H. Israel, F. P. McCoy, Mark           T
#
#                                        bib_reference  \
# 0  2016ApJ...822...36O 2017ApJ...843..136E 2019Ic...
# 1  2016ApJ...822...36O 2017ApJ...843..136E 2019Ic...
# 2  2016ApJ...822...36O 2017ApJ...843..136E 2019Ic...
# 3  2016ApJ...822...36O 2017ApJ...843..136E 2019Ic...
# 4  2014A&A...562A..96I 2017AdAst2017E...6A 2017Ap...
#
#                                      science_keyword  scientific_category  \
# 0  Active Galactic Nuclei (AGN)/Quasars (QSO), Ou...      Active galaxies
# 1  Active Galactic Nuclei (AGN)/Quasars (QSO), Ou...      Active galaxies
# 2  Active Galactic Nuclei (AGN)/Quasars (QSO), Ou...      Active galaxies
# 3  Active Galactic Nuclei (AGN)/Quasars (QSO), Ou...      Active galaxies
# 4  Galactic centres/nuclei, Active Galactic Nucle...      Active galaxies
#
#               lastModified
# 0  2021-06-16T16:46:50.431
# 1  2021-06-16T16:46:50.431
# 2  2021-06-16T16:46:50.431
# 3  2021-06-16T16:46:50.431
# 4  2021-06-16T16:46:50.431
#
# [5 rows x 63 columns]

# %% [markdown]
# <hr style="border:2px solid darkblue"> </hr>
#
# ## By Coordinate
#
# <hr style="border:2px solid darkblue"> </hr>

# %% [markdown]
# The most basic search of a source is based on its coordinates. To do this we use the SELECT task to define a function which searches all observations within a circle defined by the ADQL task CIRCLE.

# %%
def query_coord(ra, dec, radius):

    service = pyvo.dal.TAPService("https://almascience.eso.org/tap")

    query = f"""
            SELECT * 
            FROM ivoa.obscore   
            WHERE CONTAINS(  POINT('ICRS', s_ra, s_dec), 
                             CIRCLE('ICRS',{ra},{dec} ,{radius}))=1 
             """
    return service.search(query).to_table().to_pandas()

# %% [markdown]
# ## Example 1c: Find sources at coordinate RA: 350.9345, DEC: -1.046

# %%
ALMAtap_results = query_coord( 201.365063,-43.019112, 0.006)
ALMAtap_results.head(5)
# Out:
#                                           access_url access_format  \
# 0  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 1  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 2  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 3  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 4  http://almascience.org/aq?member_ous_id=uid://...     text/html
#
#       proposal_id data_rights  gal_longitude  gal_latitude  \
# 0  2011.0.00010.S      Public     309.515914     19.417224
# 1  2011.0.00628.S      Public     309.515914     19.417224
# 2  2011.0.00628.S      Public     309.515914     19.417224
# 3  2011.0.00628.S      Public     309.515914     19.417224
# 4  2011.0.00628.S      Public     309.515914     19.417224
#
#              obs_publisher_did obs_collection facility_name instrument_name  \
# 0  ADS/JAO.ALMA#2011.0.00010.S           ALMA           JAO            ALMA
# 1  ADS/JAO.ALMA#2011.0.00628.S           ALMA           JAO            ALMA
# 2  ADS/JAO.ALMA#2011.0.00628.S           ALMA           JAO            ALMA
# 3  ADS/JAO.ALMA#2011.0.00628.S           ALMA           JAO            ALMA
# 4  ADS/JAO.ALMA#2011.0.00628.S           ALMA           JAO            ALMA
#
#    ...   frequency velocity_resolution  obs_creator_name  \
# 0  ...  219.025328          663.940713      Ott, Juergen
# 1  ...  343.137988          209.208493    Jorgensen, Jes
# 2  ...  343.137988          209.208493    Jorgensen, Jes
# 3  ...  343.137988          209.208493    Jorgensen, Jes
# 4  ...  343.137988          209.208493    Jorgensen, Jes
#
#                                            pub_title  \
# 0  ALMA Observations of the Physical and Chemical...
# 1  A Recent Accretion Burst in the Low-mass Proto...
# 2  A Recent Accretion Burst in the Low-mass Proto...
# 3  A Recent Accretion Burst in the Low-mass Proto...
# 4  A Recent Accretion Burst in the Low-mass Proto...
#
#                                         first_author  qa2_passed  \
# 0                                        McCoy, Mark           T
# 1  Bjerkeli, P. Jørgensen, Jes K. Lindberg, Johan...           T
# 2  Bjerkeli, P. Jørgensen, Jes K. Lindberg, Johan...           T
# 3  Bjerkeli, P. Jørgensen, Jes K. Lindberg, Johan...           T
# 4  Bjerkeli, P. Jørgensen, Jes K. Lindberg, Johan...           T
#
#                                        bib_reference  \
# 0                                2017ApJ...851...76M
# 1  2013ApJ...779L..22J 2014A&A...566A..74L 2014Ap...
# 2  2013ApJ...779L..22J 2014A&A...566A..74L 2014Ap...
# 3  2013ApJ...779L..22J 2014A&A...566A..74L 2014Ap...
# 4  2013ApJ...779L..22J 2014A&A...566A..74L 2014Ap...
#
#                                      science_keyword  \
# 0  Active Galactic Nuclei (AGN)/Quasars (QSO), Me...
# 1        Disks around low-mass stars, Astrochemistry
# 2        Disks around low-mass stars, Astrochemistry
# 3        Disks around low-mass stars, Astrochemistry
# 4        Disks around low-mass stars, Astrochemistry
#
#           scientific_category             lastModified
# 0             Active galaxies  2021-06-16T16:46:50.431
# 1  Disks and planet formation  2021-06-16T16:46:50.431
# 2  Disks and planet formation  2021-06-16T16:46:50.431
# 3  Disks and planet formation  2021-06-16T16:46:50.431
# 4  Disks and planet formation  2021-06-16T16:46:50.431
#
# [5 rows x 63 columns]

# %% [markdown]
# <hr style="border:2px solid darkblue"> </hr>
#
# ## By Coordinate: Display distance
#
# <hr style="border:2px solid darkblue"> </hr>

# %% [markdown]
# It is also possible to add a column to the ADQL output. For example we can now display the distance of the positions in the archive catalogue to the searched coordinate.

# %%
def query_coord_display_distance(ra, dec, radius):

    service = pyvo.dal.TAPService("https://almascience.eso.org/tap")

    query = f""" SELECT DISTANCE( POINT('ICRS', s_ra, s_dec),
                                   POINT('ICRS',{ra},{dec}))
                 AS dist, * 
                 FROM ivoa.obscore 
                 WHERE CONTAINS( POINT('ICRS', s_ra, s_dec),
                                 CIRCLE('ICRS',{ra},{dec} ,{radius}))=1
             """

    return service.search(query).to_table().to_pandas()

# %%
pd.set_option('display.max_columns', None)

ALMAtap_results = query_coord_display_distance( 201.365063,-43.019112, 0.006)
ALMAtap_results.head(5)
# Out:
#    dist                                         access_url access_format  \
# 0   0.0  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 1   0.0  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 2   0.0  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 3   0.0  http://almascience.org/aq?member_ous_id=uid://...     text/html
# 4   0.0  http://almascience.org/aq?member_ous_id=uid://...     text/html
#
#       proposal_id data_rights  gal_longitude  gal_latitude  \
# 0  2011.0.00010.S      Public     309.515914     19.417224
# 1  2011.0.00628.S      Public     309.515914     19.417224
# 2  2011.0.00628.S      Public     309.515914     19.417224
# 3  2011.0.00628.S      Public     309.515914     19.417224
# 4  2011.0.00628.S      Public     309.515914     19.417224
#
#              obs_publisher_did obs_collection facility_name instrument_name  \
# 0  ADS/JAO.ALMA#2011.0.00010.S           ALMA           JAO            ALMA
# 1  ADS/JAO.ALMA#2011.0.00628.S           ALMA           JAO            ALMA
# 2  ADS/JAO.ALMA#2011.0.00628.S           ALMA           JAO            ALMA
# 3  ADS/JAO.ALMA#2011.0.00628.S           ALMA           JAO            ALMA
# 4  ADS/JAO.ALMA#2011.0.00628.S           ALMA           JAO            ALMA
#
#                     obs_id dataproduct_type  calib_level target_name  \
# 0  uid://A002/X327408/X217             cube            2        CenA
# 1   uid://A002/X327408/Xe4             cube            2   J1325-430
# 2   uid://A002/X327408/Xe4             cube            2   J1325-430
# 3   uid://A002/X327408/Xe4             cube            2   J1325-430
# 4   uid://A002/X327408/Xe4             cube            2   J1325-430
#
#          s_ra      s_dec     s_fov  \
# 0  201.365063 -43.019112  0.007385
# 1  201.365063 -43.019113  0.004714
# 2  201.365063 -43.019113  0.004714
# 3  201.365063 -43.019113  0.004714
# 4  201.365063 -43.019113  0.004714
#
#                                      s_region  s_resolution         t_min  \
# 0  Circle ICRS 201.365063 -43.019112 0.003692      1.330912  55950.253573
# 1  Circle ICRS 201.365063 -43.019113 0.002356      0.351303  56014.406696
# 2  Circle ICRS 201.365063 -43.019113 0.002356      0.351303  56014.406696
# 3  Circle ICRS 201.365063 -43.019113 0.002356      0.351303  56014.406696
# 4  Circle ICRS 201.365063 -43.019113 0.002356      0.351303  56014.406696
#
#           t_max  t_exptime  t_resolution    em_min    em_max  em_res_power  \
# 0  55950.305961     1512.0        1512.0  0.001372  0.001378  4.475829e+05
# 1  56109.095123     1209.6        1209.6  0.000888  0.000890  1.382235e+06
# 2  56109.095123     1209.6        1209.6  0.000863  0.000864  1.422914e+06
# 3  56109.095123     1209.6        1209.6  0.000889  0.000890  1.381848e+06
# 4  56109.095123     1209.6        1209.6  0.000858  0.000859  1.431100e+06
#
#   pol_states                                o_ucd band_list  em_resolution  \
# 0    /XX/YY/  phot.flux.density;phys.polarization         6   1.463715e+14
# 1    /XX/YY/  phot.flux.density;phys.polarization         7   7.318905e+13
# 2    /XX/YY/  phot.flux.density;phys.polarization         7   7.318905e+13
# 3    /XX/YY/  phot.flux.density;phys.polarization         7   7.318905e+13
# 4    /XX/YY/  phot.flux.density;phys.polarization         7   7.318905e+13
#
#                                              authors  \
# 0  McCoy, Mark; Ott, Jürgen; Meier, David S.; Mul...
# 1  Bjerkeli, P.; Jørgensen, J. K.; Bergin, E. A.;...
# 2  Bjerkeli, P.; Jørgensen, J. K.; Bergin, E. A.;...
# 3  Bjerkeli, P.; Jørgensen, J. K.; Bergin, E. A.;...
# 4  Bjerkeli, P.; Jørgensen, J. K.; Bergin, E. A.;...
#
#                                         pub_abstract  publication_year  \
# 0  Centaurus A, with its gas-rich elliptical host...              2017
# 1  Context. Changing physical conditions in the v...              2014
# 2  Context. Changing physical conditions in the v...              2014
# 3  Context. Changing physical conditions in the v...              2014
# 4  Context. Changing physical conditions in the v...              2014
#
#                                    proposal_abstract  \
# 0  Centaurus A with its host NGC5128 is the most ...
# 1  One of the key questions that ALMA will addres...
# 2  One of the key questions that ALMA will addres...
# 3  One of the key questions that ALMA will addres...
# 4  One of the key questions that ALMA will addres...
#
#                     schedblock_name  \
# 0  CenA 13CO, C18O, HNCO, H2CO COMP
# 1            IRAS_15398_B7_extended
# 2            IRAS_15398_B7_extended
# 3            IRAS_15398_B7_extended
# 4            IRAS_15398_B7_extended
#
#                                     proposal_authors  sensitivity_10kms  \
# 0  Impellizzeri, Violette; Peck, Alison; Walter, ...           1.390897
# 1  Bisschop, Suzanne; Sakai, Nami; Lindberg, Joha...           8.661346
# 2  Bisschop, Suzanne; Sakai, Nami; Lindberg, Joha...           6.525480
# 3  Bisschop, Suzanne; Sakai, Nami; Lindberg, Joha...          10.108261
# 4  Bisschop, Suzanne; Sakai, Nami; Lindberg, Joha...          10.151817
#
#    cont_sensitivity_bandwidth       pwv group_ous_uid  \
# 0                    0.061695  0.852892
# 1                    0.464776  1.262160
# 2                    0.464776  1.262160
# 3                    0.464776  1.262160
# 4                    0.464776  1.262160
#
#             member_ous_uid                 asdm_uid  \
# 0  uid://A002/X327408/X217  uid://A002/X383b50/Xc45
# 1   uid://A002/X327408/Xe4  uid://A002/X3b55d6/Xbbc
# 2   uid://A002/X327408/Xe4  uid://A002/X3b55d6/Xbbc
# 3   uid://A002/X327408/Xe4  uid://A002/X3b55d6/Xbbc
# 4   uid://A002/X327408/Xe4  uid://A002/X3b55d6/Xbbc
#
#                                            obs_title type         scan_intent  \
# 0  The Physics and Chemisty of Gas in Centaurus A...    S              TARGET
# 1  Disks and complex organics in the inner region...    S  BANDPASS PHASE WVR
# 2  Disks and complex organics in the inner region...    S  BANDPASS PHASE WVR
# 3  Disks and complex organics in the inner region...    S  BANDPASS PHASE WVR
# 4  Disks and complex organics in the inner region...    S  BANDPASS PHASE WVR
#
#   science_observation  spatial_scale_max    bandwidth  \
# 0                   T          12.599759  937500000.0
# 1                   F           2.909354  468750000.0
# 2                   F           2.909354  468750000.0
# 3                   F           2.909354  468750000.0
# 4                   F           2.909354  468750000.0
#
#                                       antenna_arrays is_mosaic  \
# 0  A002:PM02 A004:DV04 A009:DA43 A011:DV12 A013:D...         F
# 1  A003:DA41 A008:DV19 A011:DV12 A021:DV08 A025:D...         F
# 2  A003:DA41 A008:DV19 A011:DV12 A021:DV08 A025:D...         F
# 3  A003:DA41 A008:DV19 A011:DV12 A021:DV08 A025:D...         F
# 4  A003:DA41 A008:DV19 A011:DV12 A021:DV08 A025:D...         F
#
#           obs_release_date  spatial_resolution  \
# 0  2015-02-12T13:48:59.000            1.330912
# 1  2014-08-12T13:52:46.000            0.351303
# 2  2014-08-12T13:52:46.000            0.351303
# 3  2014-08-12T13:52:46.000            0.351303
# 4  2014-08-12T13:52:46.000            0.351303
#
#                                    frequency_support   frequency  \
# 0  [217.59..218.53GHz,488.28kHz,1.4mJy/beam@10km/...  219.025328
# 1  [336.89..337.36GHz,244.14kHz,10.1mJy/beam@10km...  343.137988
# 2  [336.89..337.36GHz,244.14kHz,10.1mJy/beam@10km...  343.137988
# 3  [336.89..337.36GHz,244.14kHz,10.1mJy/beam@10km...  343.137988
# 4  [336.89..337.36GHz,244.14kHz,10.1mJy/beam@10km...  343.137988
#
#    velocity_resolution obs_creator_name  \
# 0           663.940713     Ott, Juergen
# 1           209.208493   Jorgensen, Jes
# 2           209.208493   Jorgensen, Jes
# 3           209.208493   Jorgensen, Jes
# 4           209.208493   Jorgensen, Jes
#
#                                            pub_title  \
# 0  ALMA Observations of the Physical and Chemical...
# 1  A Recent Accretion Burst in the Low-mass Proto...
# 2  A Recent Accretion Burst in the Low-mass Proto...
# 3  A Recent Accretion Burst in the Low-mass Proto...
# 4  A Recent Accretion Burst in the Low-mass Proto...
#
#                                         first_author qa2_passed  \
# 0                                        McCoy, Mark          T
# 1  Bjerkeli, P. Jørgensen, Jes K. Lindberg, Johan...          T
# 2  Bjerkeli, P. Jørgensen, Jes K. Lindberg, Johan...          T
# 3  Bjerkeli, P. Jørgensen, Jes K. Lindberg, Johan...          T
# 4  Bjerkeli, P. Jørgensen, Jes K. Lindberg, Johan...          T
#
#                                        bib_reference  \
# 0                                2017ApJ...851...76M
# 1  2013ApJ...779L..22J 2014A&A...566A..74L 2014Ap...
# 2  2013ApJ...779L..22J 2014A&A...566A..74L 2014Ap...
# 3  2013ApJ...779L..22J 2014A&A...566A..74L 2014Ap...
# 4  2013ApJ...779L..22J 2014A&A...566A..74L 2014Ap...
#
#                                      science_keyword  \
# 0  Active Galactic Nuclei (AGN)/Quasars (QSO), Me...
# 1        Disks around low-mass stars, Astrochemistry
# 2        Disks around low-mass stars, Astrochemistry
# 3        Disks around low-mass stars, Astrochemistry
# 4        Disks around low-mass stars, Astrochemistry
#
#           scientific_category             lastModified
# 0             Active galaxies  2021-06-16T16:46:50.431
# 1  Disks and planet formation  2021-06-16T16:46:50.431
# 2  Disks and planet formation  2021-06-16T16:46:50.431
# 3  Disks and planet formation  2021-06-16T16:46:50.431
# 4  Disks and planet formation  2021-06-16T16:46:50.431
